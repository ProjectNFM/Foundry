# %%
import h5py
from temporaldata import Data

path = "/home/mila/s/sobralm/Foundry/data/processed/kemp_sleep_edf_2013/SC4001E0-PSG.h5"
path_bi = "/home/mila/s/sobralm/Foundry/data/processed/korczowski_brain_invaders_2014a/S001_sess-0.h5"
with h5py.File(path_bi, "r") as f:
    data = Data.from_hdf5(f, lazy=False)

# %%
data.splits
# Out:
# Data(
# fold_0=Data(
# test=LazyInterval(
#   end=<Closed HDF5 dataset>,
#   start=<Closed HDF5 dataset>,
#   target_ids=<Closed HDF5 dataset>,
#   targets=<Closed HDF5 dataset>,
#   timestamps=<Closed HDF5 dataset>
# ),
# train=LazyInterval(
#   end=<Closed HDF5 dataset>,
#   start=<Closed HDF5 dataset>,
#   target_ids=<Closed HDF5 dataset>,
#   targets=<Closed HDF5 dataset>,
#   timestamps=<Closed HDF5 dataset>
# ),
# valid=LazyInterval(
#   end=<Closed HDF5 dataset>,
#   start=<Closed HDF5 dataset>,
#   target_ids=<Closed HDF5 dataset>,
#   targets=<Closed HDF5 dataset>,
#   timestamps=<Closed HDF5 dataset>
# ),
# _absolute_start=0.0,
# ),
# fold_1=Data(
# test=LazyInterval(
#   end=<Closed HDF5 dataset>,
#   start=<Closed HDF5 dataset>,
#   target_ids=<Closed HDF5 dataset>,
#   targets=<Closed HDF5 dataset>,
#   timestamps=<Closed HDF5 dataset>
# ),
# train=LazyInterval(
#   end=<Closed HDF5 dataset>,
#   start=<Closed HDF5 dataset>,
#   target_ids=<Closed HDF5 dataset>,
# ...
