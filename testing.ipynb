# %%
from foundry.datasets import KempSleepEDF2013, KorczowskiBrainInvaders2014a, SchalkWolpawPhysionet2009

# %%
processed_dir = "./data/processed/"

# sleepedf = KempSleepEDF2013(
#     root=processed_dir,
# )

# bi = KorczowskiBrainInvaders2014a(
#     root=processed_dir,
# )

physionet = SchalkWolpawPhysionet2009(
    root=processed_dir,
)

# %%
# Out:
# SchalkWolpawPhysionet2009(n_recordings=109)
