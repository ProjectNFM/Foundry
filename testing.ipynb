# %%
from temporaldata import Data
import h5py

path = "/home/mila/s/sobralm/Foundry/data/processed/korczowski_brain_invaders_2014a/S001_sess-0.h5"

with h5py.File(path, "r") as f:
    data = Data.from_hdf5(f, lazy=False)

# %%
data.p300_trials.target_ids
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(1188,))

# %%
# Out:
# SchalkWolpawPhysionet2009(n_recordings=109)
